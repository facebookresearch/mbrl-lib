# %%
import sys
sys.path.append("..")

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.optim as optim

import mbrl.models as models
import mbrl.replay_buffer as replay_buffer

device = torch.device("cuda:0")

# %load_ext autoreload
# %autoreload 2

# %%
x_data = np.linspace(-12, 12, 10000)
y_data = np.sin(x_data)

train_val_size = 1100
train_size = 1000
train_val_idx = np.random.choice(list(range(1200, 3500)) + list(range(6500, 8800)), size=train_val_size, replace=False)
x_train = x_data[train_val_idx[:train_size]]
y_train = y_data[train_val_idx[:train_size]] + 0.1 * np.random.randn(train_size)
x_val = x_data[train_val_idx[train_size:]]
y_val = y_data[train_val_idx[train_size:]] + 0.1 * np.random.randn(train_val_size - train_size)

plt.plot(x_data, y_data, x_train, y_train, '.', x_val, y_val, '.')
plt.show()

# %%
num_members = 5
dataset_train = replay_buffer.BootstrapReplayBuffer(train_size, 256, num_members, (1,), (0,))
for i in range(train_size):
    dataset_train.add(x_train[i], 0, y_train[i], 0, False)

# %%
dataset_val = replay_buffer.IterableReplayBuffer(train_val_size - train_size, 256, (1,), (0,))
for i in range(train_val_size - train_size):
    dataset_val.add(x_val[i], 0, y_val[i], 0, False)

# %%
num_members = 5
ensemble = models.Ensemble(models.GaussianMLP, num_members, device, 1, 2, optim_lr=0.0075, num_layers=2, hid_size=10)
# Out:
#   File "<ipython-input-11-ac9261c58173>", line 2
#     ensemble = models.Ensemble(models.GaussianMLP, num_members, device, optim_lr=0.0075, 1, 2, num_layers=2, hid_size=10)
#                                                                                         ^
# SyntaxError: positional argument follows keyword argument

# %%
train_losses, val_losses = models.train_dyn_ensemble(
    ensemble, dataset_train, device, dataset_val=dataset_val, num_epochs=1500, patience=1500)
fig, ax = plt.subplots(2, 1)
ax[0].plot(train_losses)
ax[1].plot(val_losses)
plt.show()
# Out:
# best_weights found at epoch 0. Val loss:  0.389
# best_weights found at epoch 1. Val loss:  0.369
# best_weights found at epoch 2. Val loss:  0.355
# best_weights found at epoch 3. Val loss:  0.346
# best_weights found at epoch 4. Val loss:  0.340
# best_weights found at epoch 5. Val loss:  0.335
# best_weights found at epoch 6. Val loss:  0.331
# best_weights found at epoch 7. Val loss:  0.327
# best_weights found at epoch 8. Val loss:  0.323
# best_weights found at epoch 9. Val loss:  0.319
# best_weights found at epoch 10. Val loss:  0.316
# best_weights found at epoch 11. Val loss:  0.314
# best_weights found at epoch 12. Val loss:  0.312
# best_weights found at epoch 13. Val loss:  0.310
# best_weights found at epoch 14. Val loss:  0.309
# best_weights found at epoch 15. Val loss:  0.308
# best_weights found at epoch 16. Val loss:  0.308
# best_weights found at epoch 17. Val loss:  0.308
# best_weights found at epoch 18. Val loss:  0.308
# best_weights found at epoch 19. Val loss:  0.307
# best_weights found at epoch 20. Val loss:  0.306
# best_weights found at epoch 21. Val loss:  0.305
# best_weights found at epoch 22. Val loss:  0.304
# best_weights found at epoch 1191. Val loss:  0.226
# best_weights found at epoch 1210. Val loss:  0.226
# best_weights found at epoch 1215. Val loss:  0.226
# best_weights found at epoch 1217. Val loss:  0.226
# best_weights found at epoch 1219. Val loss:  0.225
# best_weights found at epoch 1220. Val loss:  0.225
# best_weights found at epoch 1224. Val loss:  0.225
# best_weights found at epoch 1234. Val loss:  0.225
# best_weights found at epoch 1235. Val loss:  0.224
# best_weights found at epoch 1245. Val loss:  0.224
# best_weights found at epoch 1286. Val loss:  0.224
# best_weights found at epoch 1297. Val loss:  0.223
# best_weights found at epoch 1298. Val loss:  0.223
# best_weights found at epoch 1299. Val loss:  0.223
# best_weights found at epoch 1304. Val loss:  0.223
# best_weights found at epoch 1319. Val loss:  0.222
# best_weights found at epoch 1320. Val loss:  0.221
# best_weights found at epoch 1324. Val loss:  0.220
# best_weights found at epoch 1356. Val loss:  0.220
# best_weights found at epoch 1380. Val loss:  0.220
# best_weights found at epoch 1381. Val loss:  0.219
# best_weights found at epoch 1401. Val loss:  0.219
# best_weights found at epoch 1404. Val loss:  0.219
# best_weights found at epoch 1405. Val loss:  0.218
# best_weights found at epoch 1406. Val loss:  0.218
# best_weights found at epoch 1407. Val loss:  0.218
# best_weights found at epoch 1433. Val loss:  0.217
# best_weights found at epoch 1436. Val loss:  0.217
# best_weights found at epoch 1437. Val loss:  0.217
# best_weights found at epoch 1446. Val loss:  0.217
# best_weights found at epoch 1447. Val loss:  0.216
# best_weights found at epoch 1448. Val loss:  0.216
# best_weights found at epoch 1467. Val loss:  0.216
# best_weights found at epoch 1468. Val loss:  0.216
# best_weights found at epoch 1469. Val loss:  0.216
# best_weights found at epoch 1470. Val loss:  0.216
# best_weights found at epoch 1487. Val loss:  0.216
# best_weights found at epoch 1494. Val loss:  0.215
# best_weights found at epoch 1497. Val loss:  0.215
# best_weights found at epoch 1498. Val loss:  0.215
# best_weights found at epoch 1499. Val loss:  0.214

# %%
x_tensor = torch.from_numpy(x_data).unsqueeze(1).float().to(device)

y_mean = np.zeros_like(y_data)
for i in range(num_members):
    net, _ = ensemble[i]
    pred = net(x_tensor)
    y_pred = pred[0][:, 0].squeeze().detach().cpu().numpy()
    y_mean += y_pred
y_mean /= num_members

y_std = np.zeros_like(y_data)
for i in range(num_members):
    net, _ = ensemble[i]
    pred = net(x_tensor)
    y_pred = pred[0][:, 0].squeeze().detach().cpu().numpy()
    y_std += (y_pred - y_mean) ** 2
y_std /= (num_members - 1)
y_std = np.sqrt(y_std)
    
plt.figure(figsize=(16, 8))
plt.plot(x_data, y_data, 'r', x_train, y_train, '.', x_data, y_mean, 'b-')
plt.fill_between(x_data, y_mean, y_mean + y_std, color='b', alpha=0.2)
plt.fill_between(x_data, y_mean - y_std, y_mean, color='b', alpha=0.2)
plt.show()
